# %% [markdown]
# # Diplomatura de Especialización en Desarrollo de Aplicaciones con Inteligencia Artificial  -  Inteligencia Artificial para Juegos (Game AI)
#
# Dr. Edwin Villanueva (evillatal@gmail.com)

# %% [markdown]
# ## Aprendizaje por refuerzo con Double Deep Q-networks  - juego CartPole
#
# Esta es una implementacion de un agente Double Deep Q-learning que aprende a equilibrar el mastil del juego CartPole. Adaptado de  https://github.com/keon/deep-q-learning
#
# Es necesario tener instalado  gym, tensorflow y keras

# %% [markdown]
# ### Clase <b>DDQNAgent</b>
#
# Esta es la clase que implementa el agente Double Deep Q-lerrning. Es una implementacion general, pudiendo ser usado en diferentes entornos de gym u otros. El constructor recibe las dimensiones del estado y la dimesion del vector de acciones posibles

# %%
import random
import gym
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

class DDQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size      # tamaño de un estado (numero de atributos que representan un estado)
        self.action_size = action_size    # tamaño del vector de acciones 
        self.memory = deque(maxlen=3000)  # define la memoria del agente (2000 registros como maximo)
        self.gamma = 0.95                 # discount rate
        self.learning_rate = 0.001        # taza de aprendizaje 
        
        self.epsilon = 1.0               # factor de exploration inicial
        self.epsilon_min = 0.01          # factor de exploration minimo
        self.epsilon_decay = 0.995       # factor de decaimiento del factor de exploracion
        self.model = self._build_model() # construye el modelo neuronal a entrenar 
        
        # construye un 2do modelo neuronal (target_model) para ayudar a estimar el target del 1er modelo (model)   
        self.target_model = self._build_model() 
        self.update_target_model()  # actualiza el target_model copiando los pesos de model
       

    def _build_model(self):
        # Define y compila un modelo de red neuronal de 3 capas: state_size entradas X 20 neuronas X 20 neuronas x action_size neuronas de salida
        model = Sequential()   # Informa que las capas que se van agregar son secuenciales
        model.add(Dense(20, input_dim=self.state_size, activation='relu')) # 1ra capa de 20 neuronas, cada neurona recibe state_size entradas (4 para CartPole), activacion relu
        model.add(Dense(20, activation='relu')) # 2da capa de 20 neuronas, funcion de activacion relu
        model.add(Dense(self.action_size, activation='linear')) # 3ra capa (salida) de action_size neuronas (2 para CartPole)
       
        model.compile(loss='mse', optimizer = Adam(lr=self.learning_rate)) # la funcion de perdida es el error cuadratico medio (mse)
        return model
    
    # Metodo para copiar los pesos de model a target_model
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # metodo para guardar una transicion del agente (experiencia): (estado, accion, reward resultante, nuevo estado, done)
    # done es un flag que indica que el entorno cayo en un estado terminal
    def remember(self, state, action, reward, next_state, done): 
        self.memory.append((state, action, reward, next_state, done))

    # retorna una accion.  
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:  # retorna una accion aleatoria con probabilidad self.epsilon
            return random.randrange(self.action_size)
        action_values = self.model.predict(state) # obtiene los q valores predichos por el modelo para cada accion
        return np.argmax(action_values[0])  # retorna la accion con el maximo q-valor predicho

    # metodo para actualizar los pesos de model con una muestra (minibatch) de la memoria de experiencias de tamaño batch_size
    def replay(self, batch_size): 
        # obtiene una muestra de su memoria de experiencias
        minibatch = random.sample(self.memory, batch_size) 
        
        # recorre cada experiencia del minibatch de experiencias
        for state, action, reward, next_state, done in minibatch:
            
            # target es el vector de Q values de las posibles acciones desde state (por defecto son los predichos por el modelo)
            target = self.model.predict(state)
            
            if done:  # si cayo en un estado terminal
                # Actualiza el Q valor del target correspondiente a action, colocando el valor Q = reward
                target[0][action] = reward   
            else:  # si  no es estado terminal 
                # Predice los valores Q del next_state usando target_model   (aqui la diferencia con DQN)
                Qvals_next_state = self.target_model.predict(next_state)[0]
                # Actualiza el Q value del target correspondiente a la accion action con el future discounted reward
                target[0][action] = reward + self.gamma * np.amax(Qvals_next_state)
 
            self.model.fit(state, target, epochs=1, verbose=0) # ajusta pesos de la red con el ejemplo: (state,target)

        # si no esta en el valor minimo del factor de exploracion -> hace un decaimiento del factor de exploracion
        if self.epsilon > self.epsilon_min: 
            self.epsilon *= self.epsilon_decay

    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Ejecutando el agente en el entorno CartPole

# %%
done = False
batch_size = 100    # tamaño del batch con el que se re-entrena el modelo neuronal
EPISODES = 500     # numero de episodios

env = gym.make('CartPole-v1')   # carga el modelo Cartpole de gym
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
agent = DDQNAgent(state_size, action_size)  # instancia el agente deep q-learning

for e in range(EPISODES):   # por cada episodio
    state = env.reset()     # resetea el entorno
    state = np.reshape(state, [1, state_size])
    for step in range(500):   # se prueba el agente hasta 500 pasos, sale de este loop cuando se cae en estado terminal (perdida de equilibrio)  
        #env.render()  # renderiza el entorno (no funciona en Colab)
        action = agent.get_action(state)   # obtiene una accion del agente
        next_state, reward, done, _ = env.step(action)  # ejecuta action en el entorno y obtiene: nuevo estado, reward y flag done (si es estado terminal)
        reward = reward if not done else -10  # si es estado terminal el reward es -10
        next_state = np.reshape(next_state, [1, state_size])
        agent.remember(state, action, reward, next_state, done) # almacena esta experiencia en la memoria del agente
        state = next_state   # actualiza el estado actual al nuevo estado
        if done:  # si es estado terminal, imprime resultados del trial. El escore del trial es el numero de pasos que logro ejecutar el agente
            agent.update_target_model()  # actualiza el target_model al final de cada trial
            print("episode: {}/{}, score: {}, e: {:.2}".format(e, EPISODES, step, agent.epsilon))
            break
    if len(agent.memory) > batch_size:  # si el agente tiene suficiente experiencias en su memoria -> ajusta su modelo neuronal 
        agent.replay(batch_size)
        
env.close()
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# episode: 0/500, score: 29, e: 1.0
# episode: 1/500, score: 31, e: 1.0
# episode: 2/500, score: 18, e: 1.0
# episode: 3/500, score: 17, e: 1.0
# episode: 4/500, score: 19, e: 1.0
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# episode: 5/500, score: 16, e: 0.99
# episode: 6/500, score: 18, e: 0.99
# episode: 7/500, score: 8, e: 0.99
# episode: 8/500, score: 17, e: 0.98
# episode: 9/500, score: 29, e: 0.98
# episode: 10/500, score: 22, e: 0.97
# episode: 11/500, score: 27, e: 0.97
# episode: 12/500, score: 12, e: 0.96
# episode: 13/500, score: 14, e: 0.96
# episode: 14/500, score: 24, e: 0.95
# episode: 15/500, score: 16, e: 0.95
# episode: 16/500, score: 18, e: 0.94
# episode: 17/500, score: 10, e: 0.94
# episode: 18/500, score: 19, e: 0.93
# episode: 19/500, score: 64, e: 0.93
# episode: 20/500, score: 25, e: 0.92
# episode: 21/500, score: 34, e: 0.92
# episode: 22/500, score: 37, e: 0.91
# episode: 23/500, score: 60, e: 0.91
# episode: 24/500, score: 19, e: 0.9
# episode: 25/500, score: 30, e: 0.9
# episode: 26/500, score: 15, e: 0.9
# episode: 27/500, score: 19, e: 0.89
# episode: 28/500, score: 11, e: 0.89
# episode: 29/500, score: 23, e: 0.88
# episode: 30/500, score: 13, e: 0.88
# episode: 31/500, score: 15, e: 0.87
# episode: 32/500, score: 13, e: 0.87
# episode: 33/500, score: 15, e: 0.86
# episode: 34/500, score: 15, e: 0.86
# episode: 35/500, score: 25, e: 0.86
# episode: 36/500, score: 15, e: 0.85
# episode: 37/500, score: 20, e: 0.85
# episode: 38/500, score: 46, e: 0.84
# episode: 39/500, score: 15, e: 0.84
# episode: 40/500, score: 23, e: 0.83
# episode: 41/500, score: 9, e: 0.83
# episode: 42/500, score: 56, e: 0.83
# episode: 43/500, score: 18, e: 0.82
# episode: 44/500, score: 17, e: 0.82
# episode: 45/500, score: 15, e: 0.81
# episode: 46/500, score: 15, e: 0.81
# episode: 47/500, score: 13, e: 0.81
# episode: 48/500, score: 25, e: 0.8
# episode: 49/500, score: 13, e: 0.8
# episode: 50/500, score: 15, e: 0.79
# episode: 51/500, score: 17, e: 0.79
# episode: 52/500, score: 28, e: 0.79
# episode: 53/500, score: 62, e: 0.78
# episode: 54/500, score: 11, e: 0.78
# episode: 55/500, score: 27, e: 0.77
# episode: 56/500, score: 47, e: 0.77
# episode: 57/500, score: 26, e: 0.77
# episode: 58/500, score: 23, e: 0.76
# episode: 59/500, score: 65, e: 0.76
# episode: 60/500, score: 40, e: 0.76
# episode: 61/500, score: 65, e: 0.75
# episode: 62/500, score: 13, e: 0.75
# episode: 63/500, score: 46, e: 0.74
# episode: 64/500, score: 55, e: 0.74
# episode: 65/500, score: 22, e: 0.74
# episode: 66/500, score: 59, e: 0.73
# episode: 67/500, score: 34, e: 0.73
# episode: 68/500, score: 9, e: 0.73
# episode: 69/500, score: 12, e: 0.72
# episode: 70/500, score: 23, e: 0.72
# episode: 71/500, score: 18, e: 0.71
# episode: 72/500, score: 39, e: 0.71
# episode: 73/500, score: 58, e: 0.71
# episode: 74/500, score: 17, e: 0.7
# episode: 75/500, score: 26, e: 0.7
# episode: 76/500, score: 38, e: 0.7
# episode: 77/500, score: 72, e: 0.69
# episode: 78/500, score: 40, e: 0.69
# episode: 79/500, score: 19, e: 0.69
# episode: 80/500, score: 95, e: 0.68
# episode: 81/500, score: 50, e: 0.68
# episode: 82/500, score: 50, e: 0.68
# episode: 83/500, score: 43, e: 0.67
# episode: 84/500, score: 31, e: 0.67
# episode: 85/500, score: 50, e: 0.67
# episode: 86/500, score: 54, e: 0.66
# episode: 87/500, score: 41, e: 0.66
# episode: 88/500, score: 82, e: 0.66
# episode: 89/500, score: 42, e: 0.65
# episode: 90/500, score: 54, e: 0.65
# episode: 91/500, score: 41, e: 0.65
# episode: 92/500, score: 42, e: 0.64
# episode: 93/500, score: 37, e: 0.64
# episode: 94/500, score: 159, e: 0.64
# episode: 95/500, score: 56, e: 0.63
# episode: 96/500, score: 31, e: 0.63
# episode: 97/500, score: 22, e: 0.63
# episode: 98/500, score: 87, e: 0.62
# episode: 99/500, score: 50, e: 0.62
# episode: 100/500, score: 82, e: 0.62
# episode: 101/500, score: 36, e: 0.61
# episode: 102/500, score: 64, e: 0.61
# episode: 103/500, score: 32, e: 0.61
# episode: 104/500, score: 32, e: 0.61
# episode: 105/500, score: 19, e: 0.6
# episode: 106/500, score: 88, e: 0.6
# episode: 107/500, score: 61, e: 0.6
# episode: 108/500, score: 66, e: 0.59
# episode: 109/500, score: 75, e: 0.59
# episode: 110/500, score: 13, e: 0.59
# episode: 111/500, score: 14, e: 0.58
# episode: 112/500, score: 62, e: 0.58
# episode: 113/500, score: 101, e: 0.58
# episode: 114/500, score: 42, e: 0.58
# episode: 115/500, score: 48, e: 0.57
# episode: 116/500, score: 51, e: 0.57
# episode: 117/500, score: 70, e: 0.57
# episode: 118/500, score: 10, e: 0.56
# episode: 119/500, score: 25, e: 0.56
# episode: 120/500, score: 89, e: 0.56
# episode: 121/500, score: 46, e: 0.56
# episode: 122/500, score: 13, e: 0.55
# episode: 123/500, score: 133, e: 0.55
# episode: 124/500, score: 68, e: 0.55
# episode: 125/500, score: 102, e: 0.55
# episode: 126/500, score: 112, e: 0.54
# episode: 127/500, score: 95, e: 0.54
# episode: 128/500, score: 67, e: 0.54
# episode: 129/500, score: 81, e: 0.53
# episode: 130/500, score: 66, e: 0.53
# episode: 131/500, score: 79, e: 0.53
# episode: 132/500, score: 100, e: 0.53
# episode: 133/500, score: 56, e: 0.52
# episode: 134/500, score: 55, e: 0.52
# episode: 135/500, score: 87, e: 0.52
# episode: 136/500, score: 82, e: 0.52
# episode: 137/500, score: 49, e: 0.51
# episode: 138/500, score: 134, e: 0.51
# episode: 139/500, score: 109, e: 0.51
# episode: 140/500, score: 38, e: 0.51
# episode: 141/500, score: 22, e: 0.5
# episode: 142/500, score: 82, e: 0.5
# episode: 143/500, score: 125, e: 0.5
# episode: 144/500, score: 98, e: 0.5
# episode: 145/500, score: 56, e: 0.49
# episode: 146/500, score: 63, e: 0.49
# episode: 147/500, score: 142, e: 0.49
# episode: 148/500, score: 73, e: 0.49
# episode: 149/500, score: 105, e: 0.48
# episode: 150/500, score: 80, e: 0.48
# episode: 151/500, score: 178, e: 0.48
# episode: 152/500, score: 144, e: 0.48
# episode: 153/500, score: 178, e: 0.47
# episode: 154/500, score: 112, e: 0.47
# episode: 155/500, score: 50, e: 0.47
# episode: 156/500, score: 173, e: 0.47
# episode: 157/500, score: 90, e: 0.46
# episode: 158/500, score: 117, e: 0.46
# episode: 159/500, score: 102, e: 0.46
# episode: 160/500, score: 59, e: 0.46
# episode: 161/500, score: 102, e: 0.46
# episode: 162/500, score: 91, e: 0.45
# episode: 163/500, score: 76, e: 0.45
# episode: 164/500, score: 167, e: 0.45
# episode: 165/500, score: 141, e: 0.45
# episode: 166/500, score: 257, e: 0.44
# episode: 167/500, score: 68, e: 0.44
# episode: 168/500, score: 31, e: 0.44
# episode: 169/500, score: 170, e: 0.44
# episode: 170/500, score: 165, e: 0.44
# episode: 171/500, score: 131, e: 0.43
# episode: 172/500, score: 170, e: 0.43
# episode: 173/500, score: 174, e: 0.43
# episode: 174/500, score: 121, e: 0.43
# episode: 175/500, score: 184, e: 0.42
# episode: 176/500, score: 278, e: 0.42
# episode: 177/500, score: 61, e: 0.42
# episode: 178/500, score: 127, e: 0.42
# episode: 179/500, score: 140, e: 0.42
# episode: 180/500, score: 94, e: 0.41
# episode: 181/500, score: 156, e: 0.41
# episode: 182/500, score: 140, e: 0.41
# episode: 183/500, score: 127, e: 0.41
# episode: 184/500, score: 121, e: 0.41
# episode: 185/500, score: 19, e: 0.4
# episode: 186/500, score: 38, e: 0.4
# episode: 187/500, score: 125, e: 0.4
# episode: 188/500, score: 154, e: 0.4
# episode: 189/500, score: 159, e: 0.4
# episode: 190/500, score: 88, e: 0.39
# episode: 191/500, score: 102, e: 0.39
# episode: 192/500, score: 120, e: 0.39
# episode: 193/500, score: 155, e: 0.39
# episode: 194/500, score: 134, e: 0.39
# episode: 195/500, score: 141, e: 0.38
# episode: 196/500, score: 210, e: 0.38
# episode: 197/500, score: 154, e: 0.38
# episode: 198/500, score: 117, e: 0.38
# episode: 199/500, score: 101, e: 0.38
# episode: 200/500, score: 80, e: 0.37
# episode: 201/500, score: 184, e: 0.37
# episode: 202/500, score: 152, e: 0.37
# episode: 203/500, score: 195, e: 0.37
# episode: 204/500, score: 293, e: 0.37
# episode: 205/500, score: 142, e: 0.37
# episode: 206/500, score: 147, e: 0.36
# episode: 207/500, score: 125, e: 0.36
# episode: 208/500, score: 131, e: 0.36
# episode: 209/500, score: 197, e: 0.36
# episode: 210/500, score: 164, e: 0.36
# episode: 211/500, score: 223, e: 0.35
# episode: 212/500, score: 204, e: 0.35
# episode: 213/500, score: 245, e: 0.35
# episode: 214/500, score: 161, e: 0.35
# episode: 215/500, score: 185, e: 0.35
# episode: 216/500, score: 229, e: 0.35
# episode: 217/500, score: 269, e: 0.34
# episode: 218/500, score: 174, e: 0.34
# episode: 219/500, score: 103, e: 0.34
# episode: 220/500, score: 445, e: 0.34
# episode: 221/500, score: 163, e: 0.34
# episode: 222/500, score: 191, e: 0.34
# episode: 223/500, score: 128, e: 0.33
# episode: 224/500, score: 174, e: 0.33
# episode: 225/500, score: 196, e: 0.33
# episode: 226/500, score: 193, e: 0.33
# episode: 227/500, score: 181, e: 0.33
# episode: 228/500, score: 172, e: 0.33
# episode: 229/500, score: 156, e: 0.32
# episode: 230/500, score: 182, e: 0.32
# episode: 231/500, score: 156, e: 0.32
# episode: 232/500, score: 162, e: 0.32
# episode: 233/500, score: 201, e: 0.32
# episode: 234/500, score: 175, e: 0.32
# episode: 235/500, score: 114, e: 0.31
# episode: 236/500, score: 135, e: 0.31
# episode: 237/500, score: 142, e: 0.31
# episode: 238/500, score: 133, e: 0.31
# episode: 239/500, score: 137, e: 0.31
# episode: 240/500, score: 184, e: 0.31
# episode: 241/500, score: 163, e: 0.3
# episode: 242/500, score: 151, e: 0.3
# episode: 243/500, score: 27, e: 0.3
# episode: 244/500, score: 147, e: 0.3
# episode: 245/500, score: 120, e: 0.3
# episode: 246/500, score: 132, e: 0.3
# episode: 247/500, score: 127, e: 0.3
# episode: 248/500, score: 184, e: 0.29
# episode: 249/500, score: 299, e: 0.29
# episode: 250/500, score: 214, e: 0.29
# episode: 251/500, score: 249, e: 0.29
# episode: 252/500, score: 172, e: 0.29
# episode: 253/500, score: 276, e: 0.29
# episode: 254/500, score: 163, e: 0.29
# episode: 255/500, score: 227, e: 0.28
# episode: 256/500, score: 151, e: 0.28
# episode: 257/500, score: 117, e: 0.28
# episode: 258/500, score: 183, e: 0.28
# episode: 259/500, score: 183, e: 0.28
# episode: 260/500, score: 143, e: 0.28
# episode: 261/500, score: 244, e: 0.28
# episode: 262/500, score: 237, e: 0.27
# episode: 263/500, score: 171, e: 0.27
# episode: 264/500, score: 153, e: 0.27
# episode: 265/500, score: 147, e: 0.27
# episode: 266/500, score: 183, e: 0.27
# episode: 267/500, score: 148, e: 0.27
# episode: 268/500, score: 133, e: 0.27
# episode: 269/500, score: 136, e: 0.26
# episode: 270/500, score: 178, e: 0.26
# episode: 271/500, score: 149, e: 0.26
# episode: 272/500, score: 161, e: 0.26
# episode: 273/500, score: 152, e: 0.26
# episode: 274/500, score: 167, e: 0.26
# episode: 275/500, score: 147, e: 0.26
# episode: 276/500, score: 226, e: 0.26
# episode: 277/500, score: 210, e: 0.25
# episode: 278/500, score: 225, e: 0.25
# episode: 279/500, score: 224, e: 0.25
# episode: 280/500, score: 148, e: 0.25
# episode: 281/500, score: 131, e: 0.25
# episode: 282/500, score: 12, e: 0.25
# episode: 283/500, score: 174, e: 0.25
# episode: 284/500, score: 32, e: 0.25
# episode: 285/500, score: 183, e: 0.24
# episode: 286/500, score: 287, e: 0.24
# episode: 287/500, score: 303, e: 0.24
# episode: 288/500, score: 14, e: 0.24
# episode: 289/500, score: 199, e: 0.24
# episode: 290/500, score: 146, e: 0.24
# episode: 291/500, score: 148, e: 0.24
# episode: 292/500, score: 185, e: 0.24
# episode: 293/500, score: 199, e: 0.23
# episode: 294/500, score: 136, e: 0.23
# episode: 295/500, score: 394, e: 0.23
# episode: 296/500, score: 309, e: 0.23
# episode: 297/500, score: 314, e: 0.23
# episode: 298/500, score: 231, e: 0.23
# episode: 299/500, score: 279, e: 0.23
# episode: 300/500, score: 204, e: 0.23
# episode: 301/500, score: 471, e: 0.23
# episode: 302/500, score: 499, e: 0.22
# episode: 303/500, score: 303, e: 0.22
# episode: 304/500, score: 235, e: 0.22
# episode: 305/500, score: 152, e: 0.22
# episode: 306/500, score: 346, e: 0.22
# episode: 307/500, score: 189, e: 0.22
# episode: 308/500, score: 232, e: 0.22
# episode: 309/500, score: 373, e: 0.22
# episode: 310/500, score: 211, e: 0.22
# episode: 311/500, score: 239, e: 0.21
# episode: 312/500, score: 247, e: 0.21
# episode: 313/500, score: 373, e: 0.21
# episode: 314/500, score: 222, e: 0.21
# episode: 315/500, score: 499, e: 0.21
# episode: 316/500, score: 489, e: 0.21
# episode: 317/500, score: 310, e: 0.21
# episode: 318/500, score: 320, e: 0.21
# episode: 319/500, score: 375, e: 0.21
# episode: 320/500, score: 304, e: 0.21
# episode: 321/500, score: 274, e: 0.2
# episode: 322/500, score: 499, e: 0.2
# episode: 323/500, score: 499, e: 0.2
# episode: 324/500, score: 471, e: 0.2
# episode: 325/500, score: 338, e: 0.2
# episode: 326/500, score: 378, e: 0.2
# episode: 327/500, score: 317, e: 0.2
# episode: 328/500, score: 499, e: 0.2
# episode: 329/500, score: 480, e: 0.2
# episode: 330/500, score: 453, e: 0.2
# episode: 331/500, score: 496, e: 0.19
# episode: 332/500, score: 491, e: 0.19
# episode: 333/500, score: 499, e: 0.19
# episode: 334/500, score: 499, e: 0.19
# episode: 335/500, score: 499, e: 0.19
# episode: 336/500, score: 499, e: 0.19
# episode: 337/500, score: 363, e: 0.19
# episode: 338/500, score: 271, e: 0.19
# episode: 339/500, score: 499, e: 0.19
# episode: 340/500, score: 207, e: 0.19
# episode: 341/500, score: 464, e: 0.18
# episode: 342/500, score: 499, e: 0.18
# episode: 343/500, score: 286, e: 0.18
# episode: 344/500, score: 499, e: 0.18
# episode: 345/500, score: 359, e: 0.18
# episode: 346/500, score: 230, e: 0.18
# episode: 347/500, score: 283, e: 0.18
# episode: 348/500, score: 241, e: 0.18
# episode: 349/500, score: 499, e: 0.18
# episode: 350/500, score: 449, e: 0.18
# episode: 351/500, score: 499, e: 0.18
# episode: 352/500, score: 252, e: 0.17
# episode: 353/500, score: 230, e: 0.17
# episode: 354/500, score: 238, e: 0.17
# episode: 355/500, score: 56, e: 0.17
# episode: 356/500, score: 256, e: 0.17
# episode: 357/500, score: 264, e: 0.17
# episode: 358/500, score: 248, e: 0.17
# episode: 359/500, score: 290, e: 0.17
# episode: 360/500, score: 230, e: 0.17
# episode: 361/500, score: 230, e: 0.17
# episode: 362/500, score: 259, e: 0.17
# episode: 363/500, score: 308, e: 0.17
# episode: 364/500, score: 263, e: 0.16
# episode: 365/500, score: 295, e: 0.16
# episode: 366/500, score: 246, e: 0.16
# episode: 367/500, score: 186, e: 0.16
# episode: 368/500, score: 379, e: 0.16
# episode: 369/500, score: 17, e: 0.16
# episode: 370/500, score: 245, e: 0.16
# episode: 371/500, score: 222, e: 0.16
# episode: 372/500, score: 267, e: 0.16
# episode: 373/500, score: 219, e: 0.16
# episode: 374/500, score: 484, e: 0.16
# episode: 375/500, score: 499, e: 0.16
# episode: 376/500, score: 230, e: 0.15
# episode: 377/500, score: 152, e: 0.15
# episode: 378/500, score: 499, e: 0.15
# episode: 379/500, score: 378, e: 0.15
# episode: 380/500, score: 259, e: 0.15
# episode: 381/500, score: 16, e: 0.15
# episode: 382/500, score: 252, e: 0.15
# episode: 383/500, score: 244, e: 0.15
# episode: 384/500, score: 266, e: 0.15
# episode: 385/500, score: 228, e: 0.15
# episode: 386/500, score: 214, e: 0.15
# episode: 387/500, score: 199, e: 0.15
# episode: 388/500, score: 165, e: 0.15
# episode: 389/500, score: 251, e: 0.15
# episode: 390/500, score: 205, e: 0.14
# episode: 391/500, score: 222, e: 0.14
# episode: 392/500, score: 264, e: 0.14
# episode: 393/500, score: 191, e: 0.14
# episode: 394/500, score: 235, e: 0.14
# episode: 395/500, score: 220, e: 0.14
# episode: 396/500, score: 301, e: 0.14
# episode: 397/500, score: 274, e: 0.14
# episode: 398/500, score: 481, e: 0.14
# episode: 399/500, score: 276, e: 0.14
# episode: 400/500, score: 499, e: 0.14
# episode: 401/500, score: 279, e: 0.14
# episode: 402/500, score: 499, e: 0.14
# episode: 403/500, score: 265, e: 0.14
# episode: 404/500, score: 236, e: 0.13
# episode: 405/500, score: 327, e: 0.13
# episode: 406/500, score: 255, e: 0.13
# episode: 407/500, score: 499, e: 0.13
# episode: 408/500, score: 10, e: 0.13
# episode: 409/500, score: 210, e: 0.13
# episode: 410/500, score: 241, e: 0.13
# episode: 411/500, score: 243, e: 0.13
# episode: 412/500, score: 224, e: 0.13
# episode: 413/500, score: 257, e: 0.13
# episode: 414/500, score: 248, e: 0.13
# episode: 415/500, score: 140, e: 0.13
# episode: 416/500, score: 194, e: 0.13
# episode: 417/500, score: 223, e: 0.13
# episode: 418/500, score: 206, e: 0.13
# episode: 419/500, score: 235, e: 0.12
# episode: 420/500, score: 203, e: 0.12
# episode: 421/500, score: 208, e: 0.12
# episode: 422/500, score: 241, e: 0.12
# episode: 423/500, score: 192, e: 0.12
# episode: 424/500, score: 206, e: 0.12
# episode: 425/500, score: 380, e: 0.12
# episode: 426/500, score: 217, e: 0.12
# episode: 427/500, score: 215, e: 0.12
# episode: 428/500, score: 227, e: 0.12
# episode: 429/500, score: 304, e: 0.12
# episode: 430/500, score: 222, e: 0.12
# episode: 431/500, score: 239, e: 0.12
# episode: 432/500, score: 245, e: 0.12
# episode: 433/500, score: 359, e: 0.12
# episode: 434/500, score: 282, e: 0.12
# episode: 435/500, score: 197, e: 0.12
# episode: 436/500, score: 221, e: 0.11
# episode: 437/500, score: 166, e: 0.11
# episode: 438/500, score: 158, e: 0.11
# episode: 439/500, score: 230, e: 0.11
# episode: 440/500, score: 192, e: 0.11
# episode: 441/500, score: 206, e: 0.11
# episode: 442/500, score: 141, e: 0.11
# episode: 443/500, score: 146, e: 0.11
# episode: 444/500, score: 249, e: 0.11
# episode: 445/500, score: 184, e: 0.11
# episode: 446/500, score: 499, e: 0.11
# episode: 447/500, score: 170, e: 0.11
# episode: 448/500, score: 194, e: 0.11
# episode: 449/500, score: 224, e: 0.11
# episode: 450/500, score: 228, e: 0.11
# episode: 451/500, score: 169, e: 0.11
# episode: 452/500, score: 235, e: 0.11
# episode: 453/500, score: 155, e: 0.11
# episode: 454/500, score: 166, e: 0.1
# episode: 455/500, score: 132, e: 0.1
# episode: 456/500, score: 146, e: 0.1
# episode: 457/500, score: 150, e: 0.1
# episode: 458/500, score: 178, e: 0.1
# episode: 459/500, score: 9, e: 0.1
# episode: 460/500, score: 94, e: 0.1
# episode: 461/500, score: 116, e: 0.1
# episode: 462/500, score: 105, e: 0.1
# episode: 463/500, score: 118, e: 0.1
# episode: 464/500, score: 99, e: 0.1
# episode: 465/500, score: 106, e: 0.099
# episode: 466/500, score: 13, e: 0.099
# episode: 467/500, score: 90, e: 0.098
# episode: 468/500, score: 110, e: 0.098
# episode: 469/500, score: 165, e: 0.097
# episode: 470/500, score: 284, e: 0.097
# episode: 471/500, score: 97, e: 0.096
# episode: 472/500, score: 118, e: 0.096
# episode: 473/500, score: 129, e: 0.095
# episode: 474/500, score: 135, e: 0.095
# episode: 475/500, score: 266, e: 0.094
# episode: 476/500, score: 194, e: 0.094
# episode: 477/500, score: 207, e: 0.093
# episode: 478/500, score: 186, e: 0.093
# episode: 479/500, score: 376, e: 0.092
# episode: 480/500, score: 203, e: 0.092
# episode: 481/500, score: 499, e: 0.092
# episode: 482/500, score: 499, e: 0.091
# episode: 483/500, score: 475, e: 0.091
# episode: 484/500, score: 265, e: 0.09
# episode: 485/500, score: 499, e: 0.09
# episode: 486/500, score: 345, e: 0.089
# episode: 487/500, score: 294, e: 0.089
# episode: 488/500, score: 284, e: 0.088
# episode: 489/500, score: 315, e: 0.088
# episode: 490/500, score: 312, e: 0.088
# episode: 491/500, score: 203, e: 0.087
# episode: 492/500, score: 329, e: 0.087
# episode: 493/500, score: 499, e: 0.086
# episode: 494/500, score: 247, e: 0.086
# episode: 495/500, score: 499, e: 0.085
# episode: 496/500, score: 334, e: 0.085
# episode: 497/500, score: 350, e: 0.084
# episode: 498/500, score: 171, e: 0.084
# episode: 499/500, score: 133, e: 0.084

# %% [markdown]
# ### Funcion para probar el agente entrenado  en el entorno CartPole
#
# play_CartPole()  no realiza entrenamiento, solo actua en el ambiente de acuerdo a su modelo aprendido previamente

# %%
def play_CartPole(agent, trials = 1):
    env = gym.make('CartPole-v1')  
    scores = []
    for trial in range(trials):
        score = 0
        game_memory = []
        state = []
        env.reset()
        for step in range(500): # en cada trial ejecuta 500  pasos
            env.render()

            if len(state) == 0:    # si es el primer movimiento  -> escoge una accion aleatoria
                action = random.randrange(0,2)
            else:
                action_values = agent.model.predict(state.reshape(1, 4)) # predice los q valores con la RN del agente
                action = np.argmax(action_values[0])      # retorna la accion con el maximo q-valor predicho

            next_state, reward, done, _  = env.step(action)  # corre el entorno un step ejecutando la accion inferida
            score += reward   # acumula el reward (reward=1 en cualquier estado no terminal)
            state = next_state
            game_memory.append([next_state, action])
            if done: 
                print("Play {}/{}, score: {}".format(trial, trials, step))
                break
        scores.append(score)
    env.close()
 
    print("Score medio = {}".format(sum(scores) /float(trials)) )

# %%
# prueba el agente 5 trials del entorno
play_CartPole(agent,5)
# Out:
# Play 0/5, score: 334
# Play 1/5, score: 323
# Play 2/5, score: 324
# Play 3/5, score: 313
# Play 4/5, score: 385
# Score medio = 336.8
