# %% [markdown]
# # Diplomatura de Especialización en Desarrollo de Aplicaciones con Inteligencia Artificial - Inteligencia Artificial para Juegos (Game AI) - Sesión 1

# %% [markdown]
# <font color='orange'>Agente aspirador en una grilla de NxN</font>

# %% [markdown]
# En el presente notebook se tiene la codificación de un agente aspirador (*VacuumAgent*) así como de un entorno tipo grilla configurable (*room*). Se busca que el agente interactúe con su entorno para limpiarlo.

# %% [markdown]
# ## Clase <b>Thing</b>
#
#   Esta clase generica representa cualquier objeto fisico que puede aparecer en un <b>Ambiente</b>.

# %%
class Thing(object):

    def is_alive(self):
        """Cosas 'vivas'deben retornar true."""
        return hasattr(self, 'alive') and self.alive

    def show_state(self):
        """Muestra el estado interno del agente. Subclases deben sobreescribir esto."""
        print("I don't know how to show_state.")

# %% [markdown]
# ## Clase <b>Agent</b>
#
# Un agente es una subclase de Thing con un slot obligatorio: <b>.program</b>, el cual almacena la funcion que implementa el <b>programa del agente</b>. Esta funcion debe tomar como argumento la <b>percepcion</b> del agente y debe retornar una <b>accion</b>. La definicion de Percepcion y Accion depende del ambiente de trabajo (environment) donde el agente existe. El agente tambien puede tener el slot <b>.performance</b>, que mide el desempeño del agente en su ambiente.

# %%
import collections

class Agent(Thing):

    def __init__(self, program=None):
        self.alive = True
        self.performance = 0
        assert isinstance(program, collections.Callable)
        self.program = program

# %% [markdown]
# ## Clase <b>Environment</b>
#
# Esta clase abstracta representa un entorno de tareas. Clases de entornos reales heredan de esta. En un entorno tipicamente se necesitará implementar 2 cosas:
# <b>percept</b>, que define la percepción que el agente ve; y
# <b>execute_action</b>, que define los efectos de ejecutar una acción.
# El entorno mantiene una lista de .things y .agents (el cual es un subconjunto de .things). Cada elemento de .things tiene un slot .location. (No editar)

# %%
class Environment(object):

    def __init__(self):
        self.things = []
        self.agents = []

    def thing_classes(self):
        return []  # List of classes that can go into environment

    def percept(self, agent):
        """Retorna la percepcion que el agente 'agent' ve en este punto."""
        raise NotImplementedError

    def execute_action(self, agent, action):
        """El agente 'agent' ejecuta una accion 'action' en el entorno."""
        raise NotImplementedError

    def default_location(self, thing):
        """Localización por defecto para colocar una nueva cosa sin localizacion especificada."""
        return None

    def is_done(self):
        """Retorna True si no hay ningun agente vivo"""
        return not any(agent.is_alive() for agent in self.agents)

    def add_thing(self, thing, location=None):
        """Añade un objeto Thing al entorno en la localizacion location. 
           Si thing es un programa de agente, crea un nuevo agente con ese programa."""
        if not isinstance(thing, Thing):
            thing = Agent(thing)
        assert thing not in self.things, "No añade la misma cosa dos veces"
        thing.location = location if location is not None else self.default_location(thing)
        self.things.append(thing)
        if isinstance(thing, Agent):
            thing.performance = 0
            self.agents.append(thing)
    
    def delete_thing(self, thing):
        """Elimina un objeto Thing al entorno en la localizacion location
        Si thing es un programa de agente, igual lo remueve.
        Remove a thing from the environment."""
        try:
            self.things.remove(thing)
        except ValueError as e:
            print(e)
            print("  in Environment delete_thing")
            print("  Thing to be removed: {} at {}".format(thing, thing.location))
            print("  from list: {}".format([(thing, thing.location) for thing in self.things]))
        if thing in self.agents:
            self.agents.remove(thing)

    def list_things_at(self, location, tclass=Thing):
        """Return all things exactly at a given location."""
        return [thing for thing in self.things
                if thing.location == location and isinstance(thing, tclass)]

    def step(self):
        """Ejecuta un paso del entorno (llama a los programas de los agentes, obtiene sus acciones y las ejecuta). """
        if not self.is_done():
            actions = []
            for agent in self.agents:
                if agent.alive:
                    actions.append(agent.program(self.percept(agent)))
                else:
                    actions.append("")
            for (agent, action) in zip(self.agents, actions):
                self.execute_action(agent, action)

    def run(self, steps=1000):
        """Ejecuta steps pasos en el entorno."""
        for step in range(steps):
            if self.is_done():
                return
            self.step()

# %% [markdown]
# ## Clase XYEnvironment

# %%
class XYEnvironment(Environment):
    """This class is for environments on a 2D plane, with locations
    labelled by (x, y) points, either discrete or continuous.

    Agents perceive things within a radius. Each agent in the
    environment has a .location slot which should be a location such
    as (0, 1), and a .holding slot, which should be a list of things
    that are held."""

    def __init__(self, width=10, height=10):
        super().__init__()

        self.width = width
        self.height = height
        self.observers = []
        # Sets iteration start and end (no walls).
        self.x_start, self.y_start = (0, 0)
        self.x_end, self.y_end = (self.width, self.height)

    perceptible_distance = 1

    def things_near(self, location, radius=None):
        """Return all things within radius of location."""
        if radius is None:
            radius = self.perceptible_distance
        radius2 = radius * radius
        return [(thing, radius2 - distance_squared(location, thing.location))
                for thing in self.things if distance_squared(
                                                location, thing.location) <= radius2]

    def percept(self, agent):
        """By default, agent perceives things within a default radius."""
        return self.things_near(agent.location)

    def execute_action(self, agent, action):
        agent.bump = False
        if action == 'TurnRight':
            agent.direction += Direction.R
        elif action == 'TurnLeft':
            agent.direction += Direction.L
        elif action == 'Forward':
            agent.bump = self.move_to(agent, agent.direction.move_forward(agent.location))
#         elif action == 'Grab':
#             things = [thing for thing in self.list_things_at(agent.location)
#                     if agent.can_grab(thing)]
#             if things:
#                 agent.holding.append(things[0])
        elif action == 'Release':
            if agent.holding:
                agent.holding.pop()

    def default_location(self, thing):
        return (random.choice(self.width), random.choice(self.height))

    def move_to(self, thing, destination):
        """Move a thing to a new location. Returns True on success or False if there is an Obstacle.
        If thing is holding anything, they move with him."""
        thing.bump = self.some_things_at(destination, Obstacle)
        if not thing.bump:
            thing.location = destination
            for o in self.observers:
                o.thing_moved(thing)
            for t in thing.holding:
                self.delete_thing(t)
                self.add_thing(t, destination)
                t.location = destination
        return thing.bump

    def add_thing(self, thing, location=(1, 1), exclude_duplicate_class_items=False):
        """Add things to the world. If (exclude_duplicate_class_items) then the item won't be
        added if the location has at least one item of the same class."""
        if (self.is_inbounds(location)):
            if (exclude_duplicate_class_items and
                    any(isinstance(t, thing.__class__) for t in self.list_things_at(location))):
                return
            super().add_thing(thing, location)

    def is_inbounds(self, location):
        """Checks to make sure that the location is inbounds (within walls if we have walls)"""
        x, y = location
        return not (x < self.x_start or x > self.x_end or y < self.y_start or y > self.y_end)

    def random_location_inbounds(self, exclude=None):
        """Returns a random location that is inbounds (within walls if we have walls)"""
        location = (random.randint(self.x_start, self.x_end),
                    random.randint(self.y_start, self.y_end))
        if exclude is not None:
            while(location == exclude):
                location = (random.randint(self.x_start, self.x_end),
                            random.randint(self.y_start, self.y_end))
        return location

    def delete_thing(self, thing):
        """Deletes thing, and everything it is holding (if thing is an agent)"""
        if isinstance(thing, Agent):
            for obj in thing.holding:
                super().delete_thing(obj)
                for obs in self.observers:
                    obs.thing_deleted(obj)

        super().delete_thing(thing)
        for obs in self.observers:
            obs.thing_deleted(thing)

    def add_walls(self):
        """Put walls around the entire perimeter of the grid."""
        for x in range(self.width):
            self.add_thing(Wall(), (x, 0))
            self.add_thing(Wall(), (x, self.height - 1))
        for y in range(1, self.height-1):
            self.add_thing(Wall(), (0, y))
            self.add_thing(Wall(), (self.width - 1, y))

        # Updates iteration start and end (with walls).
        self.x_start, self.y_start = (1, 1)
        self.x_end, self.y_end = (self.width - 1, self.height - 1)

    def add_observer(self, observer):
        """Adds an observer to the list of observers.
        An observer is typically an EnvGUI.

        Each observer is notified of changes in move_to and add_thing,
        by calling the observer's methods thing_moved(thing)
        and thing_added(thing, loc)."""
        self.observers.append(observer)

    def turn_heading(self, heading, inc):
        """Return the heading to the left (inc=+1) or right (inc=-1) of heading."""
        return turn_heading(heading, inc)
# ______________________________________________________________________________

# %% [markdown]
# ## Clases Obstacle and Wall

# %%
class Obstacle(Thing):
    """Something that can cause a bump, preventing an agent from
    moving into the same square it's in."""
    pass

class Wall(Obstacle):
    pass

# %% [markdown]
# ## Clase GraphicEnvironment

# %%
#@title Instalacion de `ipythonblocks`
# !pip install ipythonblocks
# Out:
# Requirement already satisfied: ipythonblocks in /usr/local/lib/python3.6/dist-packages (1.9.0)
# Requirement already satisfied: ipython>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipythonblocks) (5.5.0)
# Requirement already satisfied: requests>=1.0 in /usr/local/lib/python3.6/dist-packages (from ipythonblocks) (2.21.0)
# Requirement already satisfied: notebook>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipythonblocks) (5.2.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0->ipythonblocks) (1.0.16)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0->ipythonblocks) (4.4.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0->ipythonblocks) (4.7.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0->ipythonblocks) (4.3.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0->ipythonblocks) (2.1.3)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0->ipythonblocks) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0->ipythonblocks) (41.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0->ipythonblocks) (0.7.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=1.0->ipythonblocks) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=1.0->ipythonblocks) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=1.0->ipythonblocks) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=1.0->ipythonblocks) (2019.9.11)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.0->ipythonblocks) (5.6.0)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook>=4.0->ipythonblocks) (0.8.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from notebook>=4.0->ipythonblocks) (4.5.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from notebook>=4.0->ipythonblocks) (4.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.0->ipythonblocks) (2.10.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from notebook>=4.0->ipythonblocks) (5.3.3)
# Requirement already satisfied: tornado>=4 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.0->ipythonblocks) (4.5.3)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from notebook>=4.0->ipythonblocks) (4.6.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from notebook>=4.0->ipythonblocks) (0.2.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0->ipythonblocks) (0.1.7)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0->ipythonblocks) (1.12.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4.0->ipythonblocks) (0.6.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.0->ipythonblocks) (0.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.0->ipythonblocks) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.0->ipythonblocks) (1.4.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.0->ipythonblocks) (0.6.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.0->ipythonblocks) (3.1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.0->ipythonblocks) (0.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat->notebook>=4.0->ipythonblocks) (2.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->notebook>=4.0->ipythonblocks) (1.1.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->notebook>=4.0->ipythonblocks) (17.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->notebook>=4.0->ipythonblocks) (2.5.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.0->ipythonblocks) (0.5.1)

# %%
from ipythonblocks import BlockGrid
from IPython.display import HTML, display
from time import sleep
class GraphicEnvironment(XYEnvironment):
    def __init__(self, width=10, height=10, color={}, boundary=True, display=False):
        """Define all the usual XYEnvironment characteristics,
        but initialise a BlockGrid for GUI too."""
        super().__init__(width, height)
        self.grid = BlockGrid(width, height, fill=(200, 200, 200))
        if display:
            self.grid.show()
            self.visible = True
        else:
            self.visible = False
        self.bounded = boundary
        self.colors = color

    def get_world(self):
        """Returns all the items in the world in a format
        understandable by the ipythonblocks BlockGrid."""
        result = []
        x_start, y_start = (0, 0)
        x_end, y_end = self.width, self.height
        for x in range(x_start, x_end):
            row = []
            for y in range(y_start, y_end):
                row.append(self.list_things_at([x, y]))
            result.append(row)
        return result

    """
    def run(self, steps=1000, delay=1):
        "" "Run the Environment for given number of time steps,
        but update the GUI too." ""
        for step in range(steps):
            sleep(delay)
            if self.visible:
                self.reveal()
            if self.is_done():
                if self.visible:
                    self.reveal()
                return
            self.step()
        if self.visible:
            self.reveal()
    """

    def run(self, steps=10, delay=1):
        """Run the Environment for given number of time steps,
        but update the GUI too."""
        for step in range(steps):
            self.update(delay)
            if self.is_done():
                break
            self.step()
        self.update(delay)

    def update(self, delay=1):
        sleep(delay)
        if self.visible:
            self.conceal()
            self.reveal()
        else:
            self.reveal()

    def reveal(self):
        """Display the BlockGrid for this world - the last thing to be added
        at a location defines the location color."""
        self.draw_world()
        self.grid.show()
        self.visible = True

    def draw_world(self):
        self.grid[:] = (200, 200, 200)
        world = self.get_world()
        for x in range(0, len(world)):
            for y in range(0, len(world[x])):
                if len(world[x][y]):
                    self.grid[y, x] = self.colors[world[x][y][-1].__class__.__name__]

    def conceal(self):
        """Hide the BlockGrid for this world"""
        self.visible = False
        display(HTML(''))

# %% [markdown]
# ## Clase VacuumEnvironment

# %%
from IPython.core.debugger import set_trace

# %%
loc_A, loc_B, loc_C, loc_D = [0, 0], [1, 0], [0, 1], [1, 1]   # The 4 locations for the Vacuum world 2x2

import random
class VacuumEnvironment(GraphicEnvironment):
    def __init__(self, width, height, color, autoDirt=False, boundary=True, display=False, verbose=False):
        super().__init__(width, height, color, boundary, display)
        self.autoDirt = autoDirt
        self.verbose = verbose

    def thing_classes(self):
        return [VacuumBot]

    def percept(self, agent):
        '''return a list of things that are in our agent's location'''
        things = self.list_things_at(agent.location)
        return things
    
    def ValidarVal(self,a, maxVal):
        if(a<0):
          return 0
        elif(a>=maxVal):
          return maxVal-1
        else:
          return a
    
    def execute_action(self, agent, action):
        """Implementa el MAPA DE TRANSICION: Cambia la posicion del agente y/o el estado de la posicion; 
        Cada aspiracion (accion 'Suck') en una localizacion Dirt provoca un aumento de desempeño en 10 unidades.
        Cada movida efectiva Right, Left, Up o Down provoca una disminución de desempeño en 1 unidad """
        
        if action == 'Right':#aumenta en 1 el primer elemento de location
            newCord = self.ValidarVal(agent.location[0]+1, self.width)
            agent.location = [newCord, agent.location[1]]
            agent.performance -= 1
        elif action == 'Left':#disminuye en 1 el primer elemento de location
            newCord = self.ValidarVal(agent.location[0]-1, self.width)
            agent.location = [newCord, agent.location[1]]
            agent.performance -= 1
        elif action == 'Up':#disminuye en 1 el segundo elemento de location
          newCord = self.ValidarVal(agent.location[1]-1, self.width)
          agent.location = [agent.location[0], newCord]
          agent.performance -= 1
        elif action == 'Down':#aumenta en 1 el segundo elemento de location
          newCord = self.ValidarVal(agent.location[1]+1, self.width)
          agent.location = [agent.location[0], newCord]
          agent.performance -= 1
        elif action == 'Suck':
          items = self.list_things_at(agent.location, tclass=Dirt)
          if len(items) != 0:
            if(self.verbose): print("Quiero limpiar las sucias", items, "en",agent.location)
            for i in items:
              if agent.clean(i): #Have the robot clean the first item
                print('{} cleaned {} at location: {}'
                      .format(str(agent)[1:-1], str(items[0])[1:-1], agent.location))
                self.delete_thing(i) #Delete it from the Room after.
          agent.performance += 10

        #Si es que self.autoDirt está activado, aleatoriamente va a ensuciar las casillas vacias
        if(self.autoDirt==True):
          world = self.get_world()
          for x in range(0, len(world)):
            for y in range(0, len(world[x])):
              if (  len( self.list_things_at([x, y]) ) == 0  ):
                if(self.verbose): print("Estoy queriendo ensuciar en:",x,y)
                dirt = Dirt()
                numMovil = random.choice(list(range(0,100)))
                if (numMovil < 2):#probabilidad de 2% de ensuciar cada casilla
                  if(self.verbose): print("Si he ensuciado en:",x,y)
                  self.add_thing(dirt, [x, y])

    def default_location(self, thing):
        """Devuelve una posicion aleatoria para la posición inicial de la aspiradora."""
        return random.choice([loc_A, loc_B, loc_C, loc_D])

# %% [markdown]
# ## Clase Dirt

# %%
class Dirt(Thing):
    pass

# %%
dirt = Dirt()
id(dirt)
# Out:
# 139998800211080

# %%
dirt = Dirt()
id(dirt)
# Out:
# 139998800211304

# %% [markdown]
# ## Clase VacuumBot

# %%
class VacuumBot(Agent):        
    def clean(self, thing):
        '''Retorna True si es que la limpieza fue satisfactoria y False en otros casos'''
        if isinstance(thing, Dirt):
            return True
        return False

# %% [markdown]
# ## Definición de programas de agentes

# %%
def program(percepts):
  #Si alguna de mis percepciones es un Dirt, debo limpiar
  #Puede que mi primera percepción no sea un Dirt!
  for pp in percepts:
    if isinstance(pp, Dirt):
      return 'Suck'

  #si no está sucio, entonces allí está el agente. Reflexivamente, le asigno una accion para cada posicion
  for pp in percepts:      
    if pp.location == loc_A:
      return 'Right'
    elif pp.location == loc_B:
      return 'Down'
    elif pp.location == loc_C:
      return 'Up'
    elif pp.location == loc_D:
      return 'Left'

# %%
class Dirt(Thing):
    pass

# %%
dirt = Dirt()
id(dirt)
# Out:
# 139998808947400

# %%
dirt = Dirt()
id(dirt)
# Out:
# 139998808947960

# %% [markdown]
# ## Creamos y probamos el entorno

# %%
room = VacuumEnvironment(2,2, color={'VacuumBot': (200,0,0), 'Dirt': (133, 122, 111)}, autoDirt=False, verbose=False) # room width is set to 2, and height to 2
vacuumBot = VacuumBot(program)
dirt = Dirt()
moredirt = Dirt()
room.add_thing(dirt, loc_A)
room.add_thing(moredirt, loc_C)

# %%
room.get_world()
# Out:
# [[[<__main__.Dirt at 0x7f5402bd4240>], [<__main__.Dirt at 0x7f5402bd4e48>]],
#  [[], []]]

# %%
room.add_thing(vacuumBot, location=loc_C)

# %%
vacuumBot2 = VacuumBot(program)

# %%
room.add_thing(vacuumBot2, location=loc_B)

# %%
room.get_world()
# Out:
# [[[<__main__.Dirt at 0x7f5402bd4240>],
#   [<__main__.Dirt at 0x7f5402bd4e48>, <__main__.VacuumBot at 0x7f5402bd4c88>]],
#  [[<__main__.VacuumBot at 0x7f5402bd4b70>], []]]

# %%
room.autoDirt=True

# %%
room.run(20)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksfce4f4aa-d2ae-473e-90f9-06dc3e80eea5 td {border: 1px solid white;}</style><table id="blocksfce4f4aa-d2ae-473e-90f9-06dc3e80eea5" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# __main__.VacuumBot object at 0x7f5402bd4c88 cleaned __main__.Dirt object at 0x7f5402bd4e48 at location: [0, 1]
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks526c530c-d7c5-4224-bbc6-c89ae9fc6b62 td {border: 1px solid white;}</style><table id="blocks526c530c-d7c5-4224-bbc6-c89ae9fc6b62" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks1e8e7246-0ad0-4bd3-86cc-0588058cc112 td {border: 1px solid white;}</style><table id="blocks1e8e7246-0ad0-4bd3-86cc-0588058cc112" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# __main__.VacuumBot object at 0x7f5402bd4c88 cleaned __main__.Dirt object at 0x7f5402bd4240 at location: [0, 0]
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksaed3c473-278e-45a8-b17c-92bd9728edc0 td {border: 1px solid white;}</style><table id="blocksaed3c473-278e-45a8-b17c-92bd9728edc0" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksd21b3f82-bc54-4727-90a3-ff8a769f221b td {border: 1px solid white;}</style><table id="blocksd21b3f82-bc54-4727-90a3-ff8a769f221b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks56e9efd0-3f96-48d3-9249-ddade1d13008 td {border: 1px solid white;}</style><table id="blocks56e9efd0-3f96-48d3-9249-ddade1d13008" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksfa4616b8-e874-4b36-962c-589223fedf63 td {border: 1px solid white;}</style><table id="blocksfa4616b8-e874-4b36-962c-589223fedf63" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks0d2b9a4b-8631-4b70-b272-08b6426fc854 td {border: 1px solid white;}</style><table id="blocks0d2b9a4b-8631-4b70-b272-08b6426fc854" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksf4da3b77-65b5-4ba5-9f62-884b9b7375db td {border: 1px solid white;}</style><table id="blocksf4da3b77-65b5-4ba5-9f62-884b9b7375db" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# __main__.VacuumBot object at 0x7f5402bd4c88 cleaned __main__.Dirt object at 0x7f5402c02d30 at location: [1, 0]
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksa28eded0-f4fc-477f-b252-bfc34e972785 td {border: 1px solid white;}</style><table id="blocksa28eded0-f4fc-477f-b252-bfc34e972785" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks23ca0817-d915-43d0-a110-9b8bdf8c0828 td {border: 1px solid white;}</style><table id="blocks23ca0817-d915-43d0-a110-9b8bdf8c0828" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksaa314497-7f1d-45a4-83a5-826b8a7a9d4c td {border: 1px solid white;}</style><table id="blocksaa314497-7f1d-45a4-83a5-826b8a7a9d4c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksd73a9357-bab3-4ced-9300-1adcfac7ad89 td {border: 1px solid white;}</style><table id="blocksd73a9357-bab3-4ced-9300-1adcfac7ad89" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks666ac343-371b-4cd1-b592-12c5bfcdb122 td {border: 1px solid white;}</style><table id="blocks666ac343-371b-4cd1-b592-12c5bfcdb122" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksb72ded49-eff3-4e4c-bc77-3140bb453193 td {border: 1px solid white;}</style><table id="blocksb72ded49-eff3-4e4c-bc77-3140bb453193" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksdf7f5688-fa59-404c-b758-0b374d635b85 td {border: 1px solid white;}</style><table id="blocksdf7f5688-fa59-404c-b758-0b374d635b85" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksf6f76f5d-b1e3-4e78-9ef3-9d825c8dd220 td {border: 1px solid white;}</style><table id="blocksf6f76f5d-b1e3-4e78-9ef3-9d825c8dd220" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9f45b83d-1032-40c0-a29c-44c14d96acbc td {border: 1px solid white;}</style><table id="blocks9f45b83d-1032-40c0-a29c-44c14d96acbc" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks73968ea0-f42a-4820-817a-00c47ce4bae6 td {border: 1px solid white;}</style><table id="blocks73968ea0-f42a-4820-817a-00c47ce4bae6" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks6c2628b5-8a3f-40a1-926c-d3b7f8193f70 td {border: 1px solid white;}</style><table id="blocks6c2628b5-8a3f-40a1-926c-d3b7f8193f70" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksccef6126-7fb5-4c3f-b37b-ceb49c9b0966 td {border: 1px solid white;}</style><table id="blocksccef6126-7fb5-4c3f-b37b-ceb49c9b0966" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>

# %%
room.get_world()
# Out:
# [[[<__main__.VacuumBot at 0x7f5402bd4c88>,
#    <__main__.VacuumBot at 0x7f5402bd4b70>],
#   []],
#  [[], []]]

# %%
room.get_world()[0]
# Out:
# [[<__main__.VacuumBot at 0x7f5402bd4c88>,
#   <__main__.VacuumBot at 0x7f5402bd4b70>],
#  []]

# %%
room.get_world()[1]
# Out:
# [[], []]

# %%
vacuumBot.performance, vacuumBot2.performance
# Out:
# (13, -9)

# %% [markdown]
# ## Para desarrollar

# %% [markdown]
# Crear un entorno `room` de 4x4 de con dos agentes que se muevan de manera reflexiva. Se busca que puedan operar de forma autónoma y garanticen que todas las casillas del room se lleguen a limpiar constantemente. Activar la generación aleatoria de `dirt` en el entorno y modificarlo para que cada casilla tenga una probabilidad del 2% de ensuciarse.

# %%
def program_44_A(percepts):
  #Si alguna de mis percepciones es un Dirt, debo limpiar
  #Puede que mi primera percepción no sea un Dirt!
  for pp in percepts:
    if isinstance(pp, Dirt):
      return 'Suck'

  #si no está sucio, entonces allí está el agente. Reflexivamente, le asigno una accion para cada posicion
  for pp in percepts:      
    if pp.location in [[0,0],[1,0],[2,0]]:
      return 'Right'
    elif pp.location in [[1,1],[2,1],[3,1]]:
      return 'Left'
    elif pp.location == [3,0]:
      return 'Down'
    elif pp.location == [0,1]:
      return 'Up'

# %%
def program_44_B(percepts):
  #Si alguna de mis percepciones es un Dirt, debo limpiar
  #Puede que mi primera percepción no sea un Dirt!
  for pp in percepts:
    if isinstance(pp, Dirt):
      return 'Suck'

  #si no está sucio, entonces allí está el agente. Reflexivamente, le asigno una accion para cada posicion
  for pp in percepts:      
    if pp.location in [[0,3],[1,3],[2,3]]:
      return 'Right'
    elif pp.location in [[1,2],[2,2],[3,2]]:
      return 'Left'
    elif pp.location == [0,2]:
      return 'Down'
    elif pp.location == [3,3]:
      return 'Up'

# %%
room = VacuumEnvironment(4,4, color={'VacuumBot': (200,0,0), 'Dirt': (133, 122, 111)}, autoDirt=True, verbose=False) # room width is set to 2, and height to 2
vacuumBot_A = VacuumBot(program_44_A)
vacuumBot_B = VacuumBot(program_44_B)
dirt = Dirt()
moredirt = Dirt()
room.add_thing(dirt, loc_A)
room.add_thing(moredirt, loc_C)

# %%
room.add_thing(vacuumBot_A, location=[0,0])
room.add_thing(vacuumBot_B, location=[3,3])

# %%
room.get_world()
# Out:
# [[[<__main__.Dirt at 0x7f540276aeb8>, <__main__.VacuumBot at 0x7f540276a550>],
#   [<__main__.Dirt at 0x7f540276ae80>],
#   [],
#   []],
#  [[], [], [], []],
#  [[], [], [], []],
#  [[], [], [], [<__main__.VacuumBot at 0x7f540276ac50>]]]

# %%
room.run(20)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockscb5d5b85-344e-4af7-b729-46bc10afa5cc td {border: 1px solid white;}</style><table id="blockscb5d5b85-344e-4af7-b729-46bc10afa5cc" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr></tbody></table>
# __main__.VacuumBot object at 0x7f540276a550 cleaned __main__.Dirt object at 0x7f540276aeb8 at location: [0, 0]
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9639765a-0ac8-487b-ac9c-48d44e003182 td {border: 1px solid white;}</style><table id="blocks9639765a-0ac8-487b-ac9c-48d44e003182" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9ba45a06-5e11-4c3a-837c-169067854ac0 td {border: 1px solid white;}</style><table id="blocks9ba45a06-5e11-4c3a-837c-169067854ac0" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# __main__.VacuumBot object at 0x7f540276a550 cleaned __main__.Dirt object at 0x7f540276a400 at location: [1, 0]
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks0c760a59-28ea-4ca9-b6cb-ad5d82a7dcf8 td {border: 1px solid white;}</style><table id="blocks0c760a59-28ea-4ca9-b6cb-ad5d82a7dcf8" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockseb75702e-c6ab-46f3-8a76-58710446abf9 td {border: 1px solid white;}</style><table id="blockseb75702e-c6ab-46f3-8a76-58710446abf9" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# __main__.VacuumBot object at 0x7f540276ac50 cleaned __main__.Dirt object at 0x7f540276a400 at location: [0, 2]
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksec949766-4eaa-4d4b-8486-bb6bfa66cf8a td {border: 1px solid white;}</style><table id="blocksec949766-4eaa-4d4b-8486-bb6bfa66cf8a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks2c0a30df-a6d5-4f6b-8db4-acf220075b07 td {border: 1px solid white;}</style><table id="blocks2c0a30df-a6d5-4f6b-8db4-acf220075b07" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks538b486f-f07d-45d1-a849-d0f7e27bd7fc td {border: 1px solid white;}</style><table id="blocks538b486f-f07d-45d1-a849-d0f7e27bd7fc" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [3, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksf7cfeef6-c2ed-41ef-90ad-a72f1e7df1ea td {border: 1px solid white;}</style><table id="blocksf7cfeef6-c2ed-41ef-90ad-a72f1e7df1ea" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks344d3bc6-9754-4b4f-9639-a371cc0835e9 td {border: 1px solid white;}</style><table id="blocks344d3bc6-9754-4b4f-9639-a371cc0835e9" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr></tbody></table>
# __main__.VacuumBot object at 0x7f540276a550 cleaned __main__.Dirt object at 0x7f540276ae80 at location: [0, 1]
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks0c88badc-4310-4c22-aada-eca63b20cb2a td {border: 1px solid white;}</style><table id="blocks0c88badc-4310-4c22-aada-eca63b20cb2a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksc73eb3e7-2e22-4572-9d6c-367cdc5801b4 td {border: 1px solid white;}</style><table id="blocksc73eb3e7-2e22-4572-9d6c-367cdc5801b4" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# __main__.VacuumBot object at 0x7f540276a550 cleaned __main__.Dirt object at 0x7f540276ab38 at location: [0, 0]
# __main__.VacuumBot object at 0x7f540276ac50 cleaned __main__.Dirt object at 0x7f540276a358 at location: [2, 2]
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks3ded7828-c7a6-44e7-a7cb-107e0376fa2e td {border: 1px solid white;}</style><table id="blocks3ded7828-c7a6-44e7-a7cb-107e0376fa2e" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks0b06e6b4-fde6-405c-9a6b-f06ca2d6074c td {border: 1px solid white;}</style><table id="blocks0b06e6b4-fde6-405c-9a6b-f06ca2d6074c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockse89e0043-d604-46b3-bfb7-ec729e748c86 td {border: 1px solid white;}</style><table id="blockse89e0043-d604-46b3-bfb7-ec729e748c86" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# __main__.VacuumBot object at 0x7f540276a550 cleaned __main__.Dirt object at 0x7f540276a400 at location: [2, 0]
# __main__.VacuumBot object at 0x7f540276ac50 cleaned __main__.Dirt object at 0x7f540276a2b0 at location: [0, 2]
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks87d4e8dc-a4a1-4df1-83b6-fd014f9b31ed td {border: 1px solid white;}</style><table id="blocks87d4e8dc-a4a1-4df1-83b6-fd014f9b31ed" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [2, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks8637a513-e9a3-458b-b663-f41d50ce3bba td {border: 1px solid white;}</style><table id="blocks8637a513-e9a3-458b-b663-f41d50ce3bba" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [3, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks1940b70f-e57a-498f-953c-32ecc6b8a233 td {border: 1px solid white;}</style><table id="blocks1940b70f-e57a-498f-953c-32ecc6b8a233" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# __main__.VacuumBot object at 0x7f540276ac50 cleaned __main__.Dirt object at 0x7f540276af60 at location: [1, 3]
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9c363bab-c9ee-4925-a329-13f51abd323e td {border: 1px solid white;}</style><table id="blocks9c363bab-c9ee-4925-a329-13f51abd323e" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [3, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockse0095518-8c53-4149-9f3b-2bf5560d2f04 td {border: 1px solid white;}</style><table id="blockse0095518-8c53-4149-9f3b-2bf5560d2f04" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
# __main__.VacuumBot object at 0x7f540276a550 cleaned __main__.Dirt object at 0x7f540276a358 at location: [1, 1]
# __main__.VacuumBot object at 0x7f540276ac50 cleaned __main__.Dirt object at 0x7f540276a3c8 at location: [2, 3]
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9c22a974-5cbb-450f-9465-0f2f53514a3d td {border: 1px solid white;}</style><table id="blocks9c22a974-5cbb-450f-9465-0f2f53514a3d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [0, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [0, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 1]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [1, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 1]&#10;Color: (133, 122, 111)" style="width: 20px; height: 20px;background-color: rgb(133, 122, 111);"></td><td title="Index: [2, 2]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [2, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 1]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td><td title="Index: [3, 2]&#10;Color: (200, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(200, 0, 0);"></td><td title="Index: [3, 3]&#10;Color: (200, 200, 200)" style="width: 20px; height: 20px;background-color: rgb(200, 200, 200);"></td></tr></tbody></table>
